# %% [markdown]
# <a href="https://colab.research.google.com/github/kalvalaruthvik/Facial-emotional-Recognition--project/blob/main/Facial%20emotion%20detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME-K.RUTHVIK
#
# CSE-B2
#
#
# 221910302021

# %%
# !pip install opencv-python
# !pip install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#IMPORTING PACKAGES

import cv2  #By using it, one can process images and videos to identify objects, faces, or even handwriting of a human.
import matplotlib.pyplot as plt #animated, and interactive visualizations & allows users to create numerous and diverse plot types
import numpy as np

# %%
# !pip install deepface
import deepface                          #Deepface is a lightweight face recognition and facial attribute analysis,all trained data will be available
from deepface import DeepFace
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 87 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 48.7 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=84a75eb425a37fd1fa5191f83b619f8f74456b25a43d2c1e5aacc832d363ff7e
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# ...
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
img=cv2.imread('/content/happy-boy.jpg')
img

# %%
plt.imshow(img)  # There fore by default opencv is BGR

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) # To get image pic better converting to RGB

# %%
predictions = DeepFace.analyze(img)
predictions
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.10it/s]
# {'emotion': {'angry': 8.66277535815918e-13,
#   'disgust': 1.4718547048091008e-23,
#   'fear': 1.3945095163385652e-13,
#   'happy': 99.99889135360718,
#   'sad': 6.522754003590592e-08,
#   'surprise': 1.445341180073001e-06,
#   'neutral': 0.0011056748917326331},
#  'dominant_emotion': 'happy',
#  'region': {'x': 96, 'y': 35, 'w': 125, 'h': 125},
#  'age': 23,
#  'gender': 'Man',
#  'race': {'asian': 96.06104469663171,
#   'indian': 0.5509483956365822,
#   'black': 0.008459169252437383,
#   'white': 0.5504426408822919,
#   'middle eastern': 0.006026580008399785,
#   'latino hispanic': 2.823081222062184},
#  'dominant_race': 'asian'}

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
img2 = cv2.imread('/content/sad girl.jpg')
plt.imshow(img2)

# %%
plt.imshow(cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)) # To get image pic better converting to RGB

# %%
predictions = DeepFace.analyze(img2)
predictions
# Out:
# ...
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.67it/s]
# {'emotion': {'angry': 2.3216066882014275,
#   'disgust': 3.1398835176332796e-05,
#   'fear': 2.7104483917355537,
#   'happy': 0.010542322706896812,
#   'sad': 17.431296408176422,
#   'surprise': 0.01976728963200003,
#   'neutral': 77.50630378723145},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 205, 'y': 76, 'w': 115, 'h': 115},
#  'age': 27,
#  'gender': 'Woman',
#  'race': {'asian': 3.9108245170607874,
#   'indian': 0.10606921910162086,
#   'black': 0.013020168310767759,
#   'white': 84.34945847686878,
#   'middle eastern': 1.9869377158247064,
#   'latino hispanic': 9.63368994794428},
#  'dominant_race': 'white'}

# %% [markdown]
# #we are trying to draw rectangle across face

# %%
facecascade = cv2.CascadeClassifier(cv2.data.haarcascades + '/content/haarcascade_frontalface_default.xml' )

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
img=cv2.imread('/content/happy-boy.jpg')
imgGray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces = faceCascade.detectMultiScale(imgGray,1.1,4)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) # To get image pic better converting to RGB

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,
            predictions['dominant_emotion'],
            (0,50),
            font,1,
            (0,0,25),
            2,
            cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB)) # To get image pic better converting to RGB
